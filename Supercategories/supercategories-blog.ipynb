# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import lines
from matplotlib import dates
# %matplotlib inline

# %%
data = pd.read_csv('fake-data.csv')
data['date'] = pd.to_datetime(data['date'])

# %%
data
# Out:
#          date  sales
# 0  2018-01-01  2.740
# 1  2018-02-01  2.530
# 2  2018-03-01  2.670
# 3  2018-04-01  2.680
# 4  2018-05-01  2.550
# 5  2018-06-01  2.340
# 6  2018-07-01  2.666
# 7  2018-08-01  2.780
# 8  2018-09-01  2.900
# 9  2018-10-01  2.300
# 10 2018-11-01  2.550
# 11 2018-12-01  2.300
# 12 2019-01-01  2.330
# 13 2019-02-01  2.400
# 14 2019-03-01  2.340
# 15 2019-04-01  2.290
# 16 2019-05-01  2.278
# 17 2019-06-01  2.100
# 18 2019-07-01  2.320
# 19 2019-08-01  2.080
# 20 2019-09-01  1.990
# 21 2019-10-01  1.950
# 22 2019-11-01  1.890
# 23 2019-12-01  1.920

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(10, 6))
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)


plt.show()

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
plt.savefig('supercat1.png')
plt.show()

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('supercat2.png')
plt.show()

# %%
## Month formatting

month = dates.DateFormatter('%b')

## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.xaxis.set_major_formatter(month)

plt.show()

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

plt.savefig('supercat4.png')
plt.show()

# %%
## Month formatting

month = dates.DateFormatter('%b')

## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

## Set up second axes

ax1 = ax.twiny()
ax1.set_xlim(0, 4)
#ax1.set_xticks([1, 3])
#ax1.set_xticklabels(['2018', '2019'], 
                   # color='black', fontsize=15)

plt.savefig('supercat5.png')
plt.show()

# %%
## Month formatting

month = dates.DateFormatter('%b')

## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

## Set up second axes

ax1 = ax.twiny()
ax1.set_xlim(0, 4)
ax1.set_xticks([1, 3])
ax1.set_xticklabels(['2018', '2019'], 
                    color='black', fontsize=15)

plt.savefig('supercat6.png')
plt.show()

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

## Set up second axes

ax1 = ax.twiny()
ax1.set_xlim(0, 4)
ax1.set_xticks([1.03, 2.96])
#ax1.spines['top'].set_color('black')
ax1.spines['top'].set_position(('outward', -380))
ax1.set_xticklabels(['2018', '2019'], 
                    color='black', fontsize=15)

plt.savefig('supercat7.png')
plt.show()

# %%
## Month formatting

month = dates.DateFormatter('%b')

## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

## Set up second axes

ax1 = ax.twiny()
ax1.set_xlim(0, 4)
ax1.set_xticks([1.03, 2.96])
ax1.spines['top'].set_color('white')
ax1.tick_params(axis='x', colors='white')
ax1.spines['top'].set_position(('outward', -380))
ax1.set_xticklabels(['2018', '2019'], 
                    color='black', fontsize=15)

plt.savefig('supercat8.png')
plt.show()

# %%
## Set up graph

fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
fig.set_facecolor('white')
ax.set_facecolor('white')

## Plot data lines and points

ax.plot(data['date'],
        data['sales'],
        color='black', linewidth='3')

## Set axes limits
        
ax.set_ylim([0, 4.5])
ax.set_xlim(['2017-12-01', '2020-01-01'])

## Set title

ax.set_title('Sales', fontsize=20)
ax.tick_params(axis='both', labelsize=15)
ax.set_xticks(data['date'])
ax.set_xticklabels(['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])

## Set up second axes

ax1 = ax.twiny()
ax1.set_xlim(0, 4)
ax1.set_xticks([1.03, 2.96])
ax1.spines['top'].set_color('white')
ax1.tick_params(axis='x', colors='white')
ax1.spines['top'].set_position(('outward', -380))
ax1.set_xticklabels(['2018', '2019'], 
                    color='black', fontsize=15)


## Add year separator line

line = lines.Line2D([0.5125, 0.5125], [0.02, 0.125], transform=fig.transFigure,
                   color='black', linewidth=1, linestyle='-')
line.set_clip_on(False)
ax.add_line(line)
plt.savefig('supercat3.png')
plt.show()
